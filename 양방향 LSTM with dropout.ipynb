# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, concatenate,LSTM, GRU, Dense, Dropout, Bidirectional, LayerNormalization, MultiHeadAttention, Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam

# %%
##데이터 불러오기
df = pd.read_csv("C:/Users/theil/Desktop/data/1등_쓰레기봉투.csv", encoding='UTF8', parse_dates = ['납품요구접수일자'])
##df.set_index(df['납품요구접수일자'], inplace=True)
##df.pop('납품요구접수일자')
df
# Out:
#        납품요구접수일자    증감납품요구수량
# 0    2017-01-02    657000.0
# 1    2017-01-03   5657700.0
# 2    2017-01-04  10275326.0
# 3    2017-01-05   9857700.0
# 4    2017-01-06  19151000.0
# ...         ...         ...
# 1285 2021-12-23  16157700.0
# 1286 2021-12-24    184000.0
# 1287 2021-12-27   6515500.0
# 1288 2021-12-28   4030000.0
# 1289 2021-12-31   4399000.0
#
# [1290 rows x 2 columns]

# %%
def preprocess(df, label = '납품요구접수일자', timesteps = 24, predict_size = 1):
    # 12시간(timesteps) 전의 데이터를 참고 해 1시간 뒤(predict_size)를 예측하는 dataset을 생성 - train 데이터
    df = df.iloc[:,:-1]
    forecast_idx = df.columns.to_list().index(label)
    split_ratio = 0.8


    split = int(df.shape[0]*split_ratio)
    train_dataset = df[:split]
    test_dataset = df[split:]
    # 정규화
    from sklearn.preprocessing import MinMaxScaler, StandardScaler
    scaler = StandardScaler()
    train_scale = scaler.fit_transform(train_dataset) 
    test_scale = scaler.transform(test_dataset)
    def create_dataset(data, window_size, predict_size):
        X_list, y_list = [], []
        predict_size = predict_size - 1
        for i in range(len(data)):
            if (i + window_size+predict_size) < len(data):
                X_list.append(data[i:i+window_size, :])
                y_list.append(data[i+window_size+predict_size, forecast_idx])
        return np.array(X_list), np.array(y_list)


    train_X, train_y = create_dataset(train_scale, timesteps, predict_size)
    test_X, test_y = create_dataset(test_scale, timesteps, predict_size)
    train_y = train_y.reshape(train_y.shape[0],1)
    test_y = test_y.reshape(test_y.shape[0],1)

    return train_X, train_y, test_X, test_y, scaler

# %%
class Current():
    def __init__(self, df):
        self.df = df
        self.label = '납품요구접수일자'
        self.units = 128 # LSTM 노드 수
        self.dropout_rate = 0.2 # 랜덤으로 Dropout 할 비율
        self.train_X, self.train_y, self.test_X, self.test_y, self.scaler = preprocess(self.df, label=self.label, timesteps=12, predict_size=1)
        self.input_shape = (self.train_X.shape[1],self.train_X.shape[2])
    
    def inverse_transform(self, x):
        # 정규화 했던 것을 원래 값으로 돌려주는 함수
        array = np.concatenate((np.zeros((len(x), self.train_X.shape[2] - 1)), x), axis=1)
        array_transform = self.scaler.inverse_transform(array)[:,-1]

        return array_transform

    def uncertainty_loss(self,true,pred):
        # uncertainty 손실 함수
        mean = pred[:,:self.train_y.shape[-1]]
        var = pred[:,self.train_y.shape[-1]:]
        uncertainty = tf.math.exp(-1*var)
        return 0.5*uncertainty * (true-mean)**2 + 0.5*var

    def LSTM(self):
        inputs = Input(shape=self.input_shape)
        # 양방향 LSTM 2층
        x = Bidirectional(LSTM(self.units,activation='relu',input_shape=self.input_shape , return_sequences=True, dropout=self.dropout_rate, recurrent_dropout = self.dropout_rate))(inputs, training = True)
        x = Bidirectional(LSTM(self.units,activation='relu',input_shape=self.input_shape , dropout=self.dropout_rate, recurrent_dropout = self.dropout_rate))(inputs, training = True)

        # 결과 값은 2개의 Dense 층으로 가는데 한 개는 평균, 한 개는 분산 값 계산을
        mean = Dropout(rate=0.2)(x, training=True)
        mean = Dense(self.train_y.shape[-1])(mean)
        var = Dropout(rate=0.2)(x, training=True)
        var = Dense(self.train_y.shape[-1])(var)
        outputs = concatenate([mean, var])
        model = Model(inputs,outputs)

        model.compile(loss=self.uncertainty_loss, optimizer=Adam())

        return model

    def transformer_encoder(self, inputs, key_dim, num_heads, ff_dim):
        # Normalization and Attention
        x = LayerNormalization(epsilon=1e-6)(inputs)
        x = MultiHeadAttention(key_dim=key_dim, num_heads=num_heads, dropout=self.dropout_rate)(x, x)
        x = Dropout(self.dropout_rate)(x, training = True)
        res = x + inputs

        # Feed Forward
        x = LayerNormalization(epsilon=1e-6)(res)
        x = Conv1D(filters=ff_dim, kernel_size=1, activation = 'relu')(x, training = True)
        x = Dropout(0.25)(x, training = True)
        x = Conv1D(filters=inputs.shape[-1], kernel_size=1, activation = 'relu')(x, training = True)

        return x + res    

    def Transfomer_LSTM(self, key_dim = 128, num_heads=2, ff_dim=128, num_blocks=1):
        # 인코더가 LSTM
        inputs = Input(shape=self.input_shape)
        x = Bidirectional(LSTM(self.units, return_sequences=True,activation = 'relu', dropout = self.dropout_rate, recurrent_dropout = self.dropout_rate))(inputs, training = True)
        x = Bidirectional(LSTM(self.units, return_sequences=True,activation = 'relu', dropout = self.dropout_rate, recurrent_dropout = self.dropout_rate))(x, training = True)

        for _ in range(num_blocks):
            x = self.transformer_encoder(x, key_dim, num_heads, ff_dim)

        avg_pool  = GlobalAveragePooling1D()(x)
        max_pool = GlobalMaxPooling1D()(x)
        conc = concatenate([avg_pool, max_pool])

        mean = Dropout(rate=0.25)(conc, training=True)
        mean = Dense(self.train_y.shape[-1], activation = 'linear')(mean)
        var = Dropout(rate=0.25)(conc, training=True)
        var = Dense(self.train_y.shape[-1], activation = 'linear')(var)
        outputs = concatenate([mean, var])
        model = Model(inputs,outputs)

        model.compile(loss=self.uncertainty_loss, optimizer=Adam())

        return model

    def Transfomer_Conv(self, key_dim = 256, num_heads=2, ff_dim=128, num_blocks=1):
        # 인코더가 CNN
        inputs = Input(shape=self.input_shape)
        x = Conv1D(filters=self.units, kernel_size=self.train_X.shape[1], strides = 1, activation = 'relu', padding='causal')(inputs, training = True)
        x = Dropout(0.2)(x, training = True)

        for _ in range(num_blocks):
            x = self.transformer_encoder(x, key_dim, num_heads, ff_dim)

        avg_pool  = GlobalAveragePooling1D()(x)
        max_pool = GlobalMaxPooling1D()(x)
        conc = concatenate([avg_pool, max_pool])
        
        mean = Dropout(rate=0.25)(conc, training=True)
        mean = Dense(self.train_y.shape[-1])(mean)
        var = Dropout(rate=0.25)(conc, training=True)
        var = Dense(self.train_y.shape[-1])(var)
        outputs = concatenate([mean, var])
        model = Model(inputs,outputs)

        model.compile(loss=self.uncertainty_loss, optimizer=Adam())
        #model.compile(loss= MSE, optimizer=Adam(), metrics = [MSE])

        return model

    def fit(self, model, epochs = 100, batch_size = 128, show_loss = True):
        # 모델 fitting
        from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
        #early_stopping = EarlyStopping(monitor='val_loss', verbose=1, patience=50)
    
        history = model.fit(self.train_X, self.train_y, batch_size = batch_size ,epochs=epochs,validation_split=0.2, verbose=1)
        train_loss = model.evaluate(self.train_X, self.train_y)
        print('train loss: {}'.format(train_loss))

        if show_loss:
            plt.figure(figsize=(12,8))
            plt.plot(history.history['loss'], label = 'loss')
            plt.plot(history.history['val_loss'], label = 'val_loss')
            plt.legend()
            plt.title('Model Loss')
            plt.show()
        return model

    def predict_ci(self, model, n_sample, ci=2.58, show= True):
        # 랜덤 샘플링과 99% 신뢰구간 구하기
        from tqdm import tqdm
        eps = np.array([model.predict(self.test_X)[:,:self.test_y.shape[-1]] for _ in tqdm(range(n_sample))])
        ale = np.array([model.predict(self.test_X)[:,self.test_y.shape[-1]:] for _ in tqdm(range(n_sample))])
    
        y_mean = np.mean(eps, axis=0) # predictive mean
        y_var = np.var(eps, axis=0) # epistemic uncertainty
        a_u = np.exp(np.mean(ale, axis=0)) # aleatoric uncertainty


        test_y_transfrom = self.inverse_transform(self.test_y)
        y_mean_transfrom = self.inverse_transform(y_mean.reshape(-1,1))
    

        #99% 신뢰구간
        lower = y_mean - ci*y_var**0.5
        upper = y_mean + ci*y_var**0.5
        lower_transfrom = self.inverse_transform(lower.reshape(-1,1))
        upper_transfrom = self.inverse_transform(upper.reshape(-1,1))

        tf_predict = self.df[-len(self.test_X):]
        tf_predict['predict'] = y_mean_transfrom
        tf_predict['predict_low'] = lower_transfrom
        tf_predict['predict_up'] = upper_transfrom

        under_upper = upper_transfrom[1:] >= test_y_transfrom[:-1]
        over_lower = lower_transfrom[1:] <= test_y_transfrom[:-1]
        total = (under_upper == over_lower)

        # 모델 평가
        from sklearn.metrics import mean_squared_error, r2_score
        print('rmse: {}'.format(np.sqrt(mean_squared_error(self.test_y, y_mean))))
        print('r2: {}'.format(r2_score(self.test_y, y_mean)))
        print("For Uncertainty model, {} are in 99% confidence interval".format(np.mean(total)))
        

        # 모델 그래프 결과
        if show == True:
            tx = self.df.index[-self.test_y.shape[0]:]
            #tx = range(self.test_y.shape[0])

            plt.figure(figsize=(12,8))
            plt.plot(tx, test_y_transfrom,'darkgreen')
            plt.plot(tx, y_mean_transfrom, 'orangered')
            plt.xlabel('Time')
            plt.ylabel('Test')
            plt.legend(['Test','Prediction'],loc='upper right')
            plt.title('Test Predict')
            plt.show() 
        
        return tf_predict

# %%
# current 클래스 생성
current = Current(df)

# %%
# Transformer LSTM 모델로 예측
# - 양방향 LSTM 2개와 FF layer 쌓은 트랜스포머 구조
# - key_dim : multihead attention 입력 차원
# - num_head : 병렬을 얼마나 할 것인지
# - ff_dim : FF 신경망 units
# - num_blocks : 트랜스포머 블록 층 (2개 이상이면 loss 크게 증가해서 1개로 한다)
model = current.Transfomer_LSTM(key_dim = 128, num_heads=2, ff_dim=128, num_blocks=1)

# 150번 반복, Adam optimizer
model = current.fit(model=model, epochs = 150, batch_size = 256, show_loss = True)

# Monte Carlo 샘플링 20번, 99% 신뢰구간 추정
TransformerLSTM_predict = current.predict_ci(model=model, n_sample = 30, ci=2.58, show= True)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 7s 440ms/step - loss: 17.9990 - val_loss: 2.7530
# Epoch 2/150
# 4/4 [==============================] - 1s 217ms/step - loss: 2.0425 - val_loss: 3.0041
# Epoch 3/150
# 4/4 [==============================] - 1s 218ms/step - loss: 1.7910 - val_loss: 1.7525
# Epoch 4/150
# 4/4 [==============================] - 1s 245ms/step - loss: 0.8516 - val_loss: 1.9445
# Epoch 5/150
# 4/4 [==============================] - 1s 308ms/step - loss: 0.5204 - val_loss: 0.5604
# Epoch 6/150
# 4/4 [==============================] - 1s 300ms/step - loss: 0.2332 - val_loss: 0.1239
# Epoch 7/150
# 4/4 [==============================] - 1s 304ms/step - loss: 0.0992 - val_loss: 1.3843
# Epoch 8/150
# 4/4 [==============================] - 1s 308ms/step - loss: -0.0455 - val_loss: 0.4625
# Epoch 9/150
# 4/4 [==============================] - 1s 308ms/step - loss: -0.2857 - val_loss: 0.4223
# Epoch 10/150
# 4/4 [==============================] - 1s 312ms/step - loss: -0.4096 - val_loss: 1.4307
# Epoch 11/150
# 4/4 [==============================] - 1s 314ms/step - loss: -0.4944 - val_loss: 0.4986
# Epoch 12/150
# 4/4 [==============================] - 1s 321ms/step - loss: -0.6362 - val_loss: 0.6975
# Epoch 13/150
# 4/4 [==============================] - 1s 295ms/step - loss: -0.7122 - val_loss: 0.5247
# Epoch 14/150
# 4/4 [==============================] - 1s 302ms/step - loss: -0.8028 - val_loss: 0.2969
# Epoch 15/150
# 4/4 [==============================] - 1s 296ms/step - loss: -0.8243 - val_loss: -0.2590
# Epoch 16/150
# 4/4 [==============================] - 1s 283ms/step - loss: -0.8493 - val_loss: -0.2336
# Epoch 17/150
# 4/4 [==============================] - 1s 309ms/step - loss: -0.8771 - val_loss: -0.4896
# Epoch 18/150
# 4/4 [==============================] - 1s 363ms/step - loss: -0.8553 - val_loss: -0.3370
# Epoch 19/150
# 4/4 [==============================] - 2s 399ms/step - loss: -0.9289 - val_loss: -0.4623
# Epoch 20/150
# 4/4 [==============================] - 1s 325ms/step - loss: -0.9706 - val_loss: -0.4288
# Epoch 21/150
# 4/4 [==============================] - 1s 328ms/step - loss: -1.0177 - val_loss: -0.5471
# Epoch 22/150
# 4/4 [==============================] - 1s 295ms/step - loss: -1.0254 - val_loss: 0.0137
# Epoch 23/150
# 4/4 [==============================] - 1s 282ms/step - loss: -1.0587 - val_loss: 0.9796
# Epoch 24/150
# 4/4 [==============================] - 1s 290ms/step - loss: -0.8005 - val_loss: 0.6998
# Epoch 25/150
# 4/4 [==============================] - 1s 320ms/step - loss: -0.8849 - val_loss: -0.1015
# Epoch 26/150
# 4/4 [==============================] - 1s 329ms/step - loss: -0.9990 - val_loss: -0.8077
# Epoch 27/150
# 4/4 [==============================] - 1s 285ms/step - loss: -1.0922 - val_loss: -0.3790
# Epoch 28/150
# 4/4 [==============================] - 1s 284ms/step - loss: -1.0828 - val_loss: -0.5873
# Epoch 29/150
# 4/4 [==============================] - 1s 356ms/step - loss: -1.1362 - val_loss: 0.2016
# Epoch 30/150
# 4/4 [==============================] - 1s 293ms/step - loss: -1.0406 - val_loss: -0.4104
# Epoch 31/150
# 4/4 [==============================] - 1s 297ms/step - loss: -1.1388 - val_loss: -0.7361
# Epoch 32/150
# 4/4 [==============================] - 1s 368ms/step - loss: -1.1722 - val_loss: -0.4503
# Epoch 33/150
# 4/4 [==============================] - 1s 299ms/step - loss: -1.2085 - val_loss: -0.7574
# Epoch 34/150
# 4/4 [==============================] - 1s 301ms/step - loss: -1.2054 - val_loss: -0.9927
# Epoch 35/150
# 4/4 [==============================] - 2s 374ms/step - loss: -1.2405 - val_loss: -0.6616
# Epoch 36/150
# 4/4 [==============================] - 1s 353ms/step - loss: -1.2342 - val_loss: -9.0166e-04
# Epoch 37/150
# 4/4 [==============================] - 1s 321ms/step - loss: -0.7751 - val_loss: 0.3729
# Epoch 38/150
# 4/4 [==============================] - 1s 319ms/step - loss: -0.8896 - val_loss: -0.8110
# Epoch 39/150
# 4/4 [==============================] - 1s 290ms/step - loss: -1.1158 - val_loss: -0.8452
# Epoch 40/150
# 4/4 [==============================] - 1s 307ms/step - loss: -1.1693 - val_loss: -0.4716
# Epoch 41/150
# 4/4 [==============================] - 1s 275ms/step - loss: -1.2382 - val_loss: -0.8450
# Epoch 42/150
# 4/4 [==============================] - 1s 313ms/step - loss: -1.2698 - val_loss: -0.6137
# Epoch 43/150
# 4/4 [==============================] - 2s 407ms/step - loss: -1.2435 - val_loss: -1.1418
# Epoch 44/150
# 4/4 [==============================] - 2s 386ms/step - loss: -1.2557 - val_loss: -0.6347
# Epoch 45/150
# 4/4 [==============================] - 1s 360ms/step - loss: -1.3405 - val_loss: -0.8346
# Epoch 46/150
# 4/4 [==============================] - 2s 372ms/step - loss: -1.3483 - val_loss: -0.1261
# Epoch 47/150
# 4/4 [==============================] - 1s 304ms/step - loss: -1.4146 - val_loss: -0.8233
# Epoch 48/150
# 4/4 [==============================] - 1s 300ms/step - loss: -1.3799 - val_loss: 0.3221
# Epoch 49/150
# 4/4 [==============================] - 1s 295ms/step - loss: -1.2484 - val_loss: -0.6674
# Epoch 50/150
# 4/4 [==============================] - 1s 297ms/step - loss: -1.2633 - val_loss: -0.7952
# Epoch 51/150
# 4/4 [==============================] - 1s 286ms/step - loss: -1.3917 - val_loss: -0.2344
# Epoch 52/150
# 4/4 [==============================] - 1s 288ms/step - loss: -1.4005 - val_loss: -0.9728
# Epoch 53/150
# 4/4 [==============================] - 1s 292ms/step - loss: -1.4928 - val_loss: -0.8296
# Epoch 54/150
# 4/4 [==============================] - 1s 272ms/step - loss: -1.4889 - val_loss: 0.2723
# Epoch 55/150
# 4/4 [==============================] - 1s 301ms/step - loss: -0.3719 - val_loss: -0.0404
# Epoch 56/150
# 4/4 [==============================] - 1s 293ms/step - loss: -0.5801 - val_loss: -0.4682
# Epoch 57/150
# 4/4 [==============================] - 1s 304ms/step - loss: -0.5090 - val_loss: -0.5712
# Epoch 58/150
# 4/4 [==============================] - 1s 289ms/step - loss: -0.8288 - val_loss: -0.6461
# Epoch 59/150
# 4/4 [==============================] - 1s 315ms/step - loss: -1.0929 - val_loss: -0.2320
# Epoch 60/150
# 4/4 [==============================] - 1s 288ms/step - loss: -1.1225 - val_loss: 0.4332
# Epoch 61/150
# 4/4 [==============================] - 1s 292ms/step - loss: -1.2188 - val_loss: -0.6737
# Epoch 62/150
# 4/4 [==============================] - 1s 297ms/step - loss: -1.2836 - val_loss: -1.0297
# Epoch 63/150
# 4/4 [==============================] - 1s 306ms/step - loss: -1.2828 - val_loss: -1.0231
# Epoch 64/150
# 4/4 [==============================] - 1s 306ms/step - loss: -1.4618 - val_loss: -0.8685
# Epoch 65/150
# 4/4 [==============================] - 1s 296ms/step - loss: -1.5021 - val_loss: -0.8618
# Epoch 66/150
# 4/4 [==============================] - 1s 313ms/step - loss: -1.4892 - val_loss: -0.3211
# Epoch 67/150
# 4/4 [==============================] - 1s 326ms/step - loss: -1.5565 - val_loss: -0.9015
# Epoch 68/150
# 4/4 [==============================] - 2s 369ms/step - loss: -1.5280 - val_loss: -1.0738
# Epoch 69/150
# 4/4 [==============================] - 1s 315ms/step - loss: -1.5650 - val_loss: -0.6223
# Epoch 70/150
# 4/4 [==============================] - 1s 293ms/step - loss: -1.5308 - val_loss: -0.9287
# Epoch 71/150
# 4/4 [==============================] - 1s 317ms/step - loss: -1.5463 - val_loss: -0.4650
# Epoch 72/150
# 4/4 [==============================] - 1s 315ms/step - loss: -1.4929 - val_loss: 0.3076
# Epoch 73/150
# 4/4 [==============================] - 1s 313ms/step - loss: -1.2063 - val_loss: 0.2110
# Epoch 74/150
# 4/4 [==============================] - 1s 327ms/step - loss: -1.3654 - val_loss: -1.0795
# Epoch 75/150
# 4/4 [==============================] - 1s 333ms/step - loss: -1.4606 - val_loss: -0.7823
# Epoch 76/150
# 4/4 [==============================] - 1s 330ms/step - loss: -1.4644 - val_loss: -1.0510
# Epoch 77/150
# 4/4 [==============================] - 1s 305ms/step - loss: -1.4216 - val_loss: -1.1214
# Epoch 78/150
# 4/4 [==============================] - 1s 325ms/step - loss: -1.4532 - val_loss: -1.2316
# Epoch 79/150
# 4/4 [==============================] - 1s 334ms/step - loss: -1.4814 - val_loss: -0.5209
# Epoch 80/150
# 4/4 [==============================] - 1s 312ms/step - loss: -1.6280 - val_loss: -1.0873
# Epoch 81/150
# 4/4 [==============================] - 1s 343ms/step - loss: -1.7020 - val_loss: -0.8654
# Epoch 82/150
# 4/4 [==============================] - 1s 331ms/step - loss: -1.0306 - val_loss: -1.1827
# Epoch 83/150
# 4/4 [==============================] - 1s 310ms/step - loss: -1.1639 - val_loss: -0.1497
# Epoch 84/150
# 4/4 [==============================] - 1s 310ms/step - loss: -1.1044 - val_loss: -1.1281
# Epoch 85/150
# 4/4 [==============================] - 1s 307ms/step - loss: -1.3142 - val_loss: -0.4466
# Epoch 86/150
# 4/4 [==============================] - 1s 314ms/step - loss: -1.5451 - val_loss: -0.6080
# Epoch 87/150
# 4/4 [==============================] - 1s 324ms/step - loss: -1.4419 - val_loss: 0.0946
# Epoch 88/150
# 4/4 [==============================] - 1s 320ms/step - loss: -1.5891 - val_loss: -1.2716
# Epoch 89/150
# 4/4 [==============================] - 1s 315ms/step - loss: -1.6242 - val_loss: -0.8398
# Epoch 90/150
# 4/4 [==============================] - 1s 341ms/step - loss: -1.7223 - val_loss: -1.2489
# Epoch 91/150
# 4/4 [==============================] - 1s 304ms/step - loss: -1.5042 - val_loss: -0.8896
# Epoch 92/150
# 4/4 [==============================] - 1s 321ms/step - loss: -1.6453 - val_loss: -0.0266
# Epoch 93/150
# 4/4 [==============================] - 1s 320ms/step - loss: -1.7023 - val_loss: -1.1257
# Epoch 94/150
# 4/4 [==============================] - 1s 336ms/step - loss: -1.7862 - val_loss: -0.6889
# Epoch 95/150
# 4/4 [==============================] - 1s 316ms/step - loss: -1.6427 - val_loss: -0.7335
# Epoch 96/150
# 4/4 [==============================] - 1s 323ms/step - loss: -1.5344 - val_loss: -0.9133
# Epoch 97/150
# 4/4 [==============================] - 1s 313ms/step - loss: -1.5218 - val_loss: -1.3197
# Epoch 98/150
# 4/4 [==============================] - 1s 311ms/step - loss: -1.5532 - val_loss: -0.5344
# Epoch 99/150
# 4/4 [==============================] - 1s 319ms/step - loss: -1.7066 - val_loss: -0.9260
# Epoch 100/150
# 4/4 [==============================] - 1s 325ms/step - loss: -1.4644 - val_loss: -1.0746
# Epoch 101/150
# 4/4 [==============================] - 1s 326ms/step - loss: -1.6926 - val_loss: -1.2592
# Epoch 102/150
# 4/4 [==============================] - 1s 324ms/step - loss: -1.7295 - val_loss: -1.4213
# Epoch 103/150
# 4/4 [==============================] - 1s 320ms/step - loss: -1.6757 - val_loss: -1.3307
# Epoch 104/150
# 4/4 [==============================] - 1s 313ms/step - loss: -1.6293 - val_loss: -1.3732
# Epoch 105/150
# 4/4 [==============================] - 1s 311ms/step - loss: -1.5638 - val_loss: -1.3060
# Epoch 106/150
# 4/4 [==============================] - 1s 322ms/step - loss: -1.6215 - val_loss: -1.2563
# Epoch 107/150
# 4/4 [==============================] - 1s 344ms/step - loss: -1.6575 - val_loss: -0.5616
# Epoch 108/150
# 4/4 [==============================] - 1s 330ms/step - loss: -1.6892 - val_loss: -1.1698
# Epoch 109/150
# 4/4 [==============================] - 1s 337ms/step - loss: -1.6974 - val_loss: 0.2237
# Epoch 110/150
# 4/4 [==============================] - 1s 312ms/step - loss: -1.6774 - val_loss: -0.7976
# Epoch 111/150
# 4/4 [==============================] - 1s 319ms/step - loss: -1.6838 - val_loss: -1.0841
# Epoch 112/150
# 4/4 [==============================] - 1s 333ms/step - loss: -1.7183 - val_loss: -1.2679
# Epoch 113/150
# 4/4 [==============================] - 1s 330ms/step - loss: -1.7566 - val_loss: -1.1802
# Epoch 114/150
# 4/4 [==============================] - 1s 336ms/step - loss: -1.9058 - val_loss: -0.1856
# Epoch 115/150
# 4/4 [==============================] - 1s 323ms/step - loss: -1.7809 - val_loss: -0.7345
# Epoch 116/150
# 4/4 [==============================] - 1s 338ms/step - loss: -1.8128 - val_loss: -1.2505
# Epoch 117/150
# 4/4 [==============================] - 1s 333ms/step - loss: -1.9030 - val_loss: -1.0270
# Epoch 118/150
# 4/4 [==============================] - 1s 340ms/step - loss: -1.9299 - val_loss: -1.3359
# Epoch 119/150
# 4/4 [==============================] - 1s 350ms/step - loss: -1.7064 - val_loss: -0.8938
# Epoch 120/150
# 4/4 [==============================] - 1s 349ms/step - loss: -1.5123 - val_loss: -1.3447
# Epoch 121/150
# 4/4 [==============================] - 1s 340ms/step - loss: -1.5804 - val_loss: -1.2613
# Epoch 122/150
# 4/4 [==============================] - 1s 336ms/step - loss: -1.7346 - val_loss: -1.2353
# Epoch 123/150
# 4/4 [==============================] - 1s 329ms/step - loss: -1.8127 - val_loss: -1.0770
# Epoch 124/150
# 4/4 [==============================] - 1s 326ms/step - loss: -1.8414 - val_loss: -1.0866
# Epoch 125/150
# 4/4 [==============================] - 1s 343ms/step - loss: -1.9359 - val_loss: -1.0567
# Epoch 126/150
# 4/4 [==============================] - 1s 340ms/step - loss: -1.9703 - val_loss: -0.7042
# Epoch 127/150
# 4/4 [==============================] - 1s 340ms/step - loss: -1.9384 - val_loss: -0.9715
# Epoch 128/150
# 4/4 [==============================] - 1s 337ms/step - loss: -1.3770 - val_loss: -1.2601
# Epoch 129/150
# 4/4 [==============================] - 1s 323ms/step - loss: -1.5861 - val_loss: -1.1440
# Epoch 130/150
# 4/4 [==============================] - 1s 352ms/step - loss: -1.5000 - val_loss: -1.1571
# Epoch 131/150
# 4/4 [==============================] - 1s 341ms/step - loss: -1.6917 - val_loss: -1.2158
# Epoch 132/150
# 4/4 [==============================] - 1s 354ms/step - loss: -1.6847 - val_loss: -0.9921
# Epoch 133/150
# 4/4 [==============================] - 1s 342ms/step - loss: -1.6576 - val_loss: -1.2213
# Epoch 134/150
# 4/4 [==============================] - 1s 339ms/step - loss: -1.8069 - val_loss: -0.9886
# Epoch 135/150
# 4/4 [==============================] - 1s 340ms/step - loss: -1.8087 - val_loss: -1.0449
# Epoch 136/150
# 4/4 [==============================] - 1s 333ms/step - loss: -1.9855 - val_loss: -0.6182
# Epoch 137/150
# 4/4 [==============================] - 1s 349ms/step - loss: -1.8606 - val_loss: -0.9643
# Epoch 138/150
# 4/4 [==============================] - 1s 346ms/step - loss: -1.9363 - val_loss: -0.6754
# Epoch 139/150
# 4/4 [==============================] - 1s 354ms/step - loss: -1.9432 - val_loss: 0.0610
# Epoch 140/150
# 4/4 [==============================] - 1s 353ms/step - loss: -1.9014 - val_loss: -0.8639
# Epoch 141/150
# 4/4 [==============================] - 1s 350ms/step - loss: -2.0096 - val_loss: -0.9360
# Epoch 142/150
# 4/4 [==============================] - 1s 345ms/step - loss: -1.6711 - val_loss: -1.2590
# Epoch 143/150
# 4/4 [==============================] - 1s 342ms/step - loss: -1.7857 - val_loss: -1.1136
# Epoch 144/150
# 4/4 [==============================] - 1s 351ms/step - loss: -1.7614 - val_loss: -1.2000
# Epoch 145/150
# 4/4 [==============================] - 1s 353ms/step - loss: -1.9232 - val_loss: -0.6322
# Epoch 146/150
# 4/4 [==============================] - 1s 353ms/step - loss: -1.8870 - val_loss: -0.9459
# Epoch 147/150
# 4/4 [==============================] - 1s 352ms/step - loss: -1.9225 - val_loss: -1.3096
# Epoch 148/150
# 4/4 [==============================] - 1s 346ms/step - loss: -1.9548 - val_loss: -0.7756
# Epoch 149/150
# 4/4 [==============================] - 1s 343ms/step - loss: -2.0079 - val_loss: -0.6861
# Epoch 150/150
# 4/4 [==============================] - 1s 356ms/step - loss: -1.9661 - val_loss: -0.9827
# 32/32 [==============================] - 1s 31ms/step - loss: -1.8849
# train loss: -1.8849217891693115
# 100%|██████████| 30/30 [00:08<00:00,  3.66it/s]
# 100%|██████████| 30/30 [00:07<00:00,  4.07it/s]
# rmse: 1.1416275349098581
# r2: -26.298501677266323
# For Uncertainty model, 1.0 are in 99% confidence interval

# %%
# LSTM 모델
model2 = current.Transfomer_Conv(key_dim = 128, num_heads=2, ff_dim=128, num_blocks=1)
model2 = current.fit(model=model2, epochs = 150, batch_size = 256, show_loss = True)
Conv_predict = current.predict_ci(model=model2, n_sample = 30, ci=2.58, show= True)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 107ms/step - loss: 1.3810 - val_loss: 1.1237
# Epoch 2/150
# 4/4 [==============================] - 0s 62ms/step - loss: 0.7983 - val_loss: 0.7177
# Epoch 3/150
# 4/4 [==============================] - 0s 69ms/step - loss: 0.4066 - val_loss: 2.9401
# Epoch 4/150
# 4/4 [==============================] - 0s 73ms/step - loss: 0.3262 - val_loss: 0.4476
# Epoch 5/150
# 4/4 [==============================] - 0s 75ms/step - loss: 0.1715 - val_loss: 0.3821
# Epoch 6/150
# 4/4 [==============================] - 0s 83ms/step - loss: -0.0339 - val_loss: 0.2877
# Epoch 7/150
# 4/4 [==============================] - 0s 79ms/step - loss: -0.1490 - val_loss: 0.9413
# Epoch 8/150
# 4/4 [==============================] - 0s 79ms/step - loss: -0.2918 - val_loss: 0.1357
# Epoch 9/150
# 4/4 [==============================] - 0s 79ms/step - loss: -0.3250 - val_loss: 0.2172
# Epoch 10/150
# 4/4 [==============================] - 0s 78ms/step - loss: -0.4390 - val_loss: -0.3119
# Epoch 11/150
# 4/4 [==============================] - 0s 78ms/step - loss: -0.5104 - val_loss: 0.5193
# Epoch 12/150
# 4/4 [==============================] - 0s 88ms/step - loss: -0.6171 - val_loss: -0.1430
# Epoch 13/150
# 4/4 [==============================] - 0s 83ms/step - loss: -0.6937 - val_loss: -0.4684
# Epoch 14/150
# 4/4 [==============================] - 0s 80ms/step - loss: -0.7057 - val_loss: 0.1593
# Epoch 15/150
# 4/4 [==============================] - 0s 81ms/step - loss: -0.7268 - val_loss: -0.2437
# Epoch 16/150
# 4/4 [==============================] - 0s 79ms/step - loss: -0.8183 - val_loss: 0.0411
# Epoch 17/150
# 4/4 [==============================] - 0s 80ms/step - loss: -0.8443 - val_loss: 0.4366
# Epoch 18/150
# 4/4 [==============================] - 0s 81ms/step - loss: -0.8982 - val_loss: -0.2704
# Epoch 19/150
# 4/4 [==============================] - 0s 78ms/step - loss: -0.9209 - val_loss: 0.8797
# Epoch 20/150
# 4/4 [==============================] - 0s 80ms/step - loss: -0.9274 - val_loss: -0.7745
# Epoch 21/150
# 4/4 [==============================] - 0s 78ms/step - loss: -0.9044 - val_loss: 0.4443
# Epoch 22/150
# 4/4 [==============================] - 0s 83ms/step - loss: -0.9511 - val_loss: -0.1324
# Epoch 23/150
# 4/4 [==============================] - 0s 80ms/step - loss: -0.8678 - val_loss: -0.0303
# Epoch 24/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.0718 - val_loss: -0.4732
# Epoch 25/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.1481 - val_loss: 1.7614
# Epoch 26/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.0230 - val_loss: 0.0237
# Epoch 27/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.0819 - val_loss: -0.9582
# Epoch 28/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.1379 - val_loss: -0.4711
# Epoch 29/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.2006 - val_loss: -0.6996
# Epoch 30/150
# 4/4 [==============================] - 0s 81ms/step - loss: -1.2542 - val_loss: -0.1190
# Epoch 31/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.3005 - val_loss: -0.8252
# Epoch 32/150
# 4/4 [==============================] - 0s 87ms/step - loss: -1.3240 - val_loss: -0.8962
# Epoch 33/150
# 4/4 [==============================] - 0s 85ms/step - loss: -1.3431 - val_loss: -0.7063
# Epoch 34/150
# 4/4 [==============================] - 0s 82ms/step - loss: -1.3985 - val_loss: 0.0071
# Epoch 35/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.4378 - val_loss: -0.7200
# Epoch 36/150
# 4/4 [==============================] - 0s 82ms/step - loss: -1.3882 - val_loss: -0.4656
# Epoch 37/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.3888 - val_loss: 0.0038
# Epoch 38/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.4209 - val_loss: 2.1110
# Epoch 39/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.3351 - val_loss: -0.4305
# Epoch 40/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.3511 - val_loss: -0.8783
# Epoch 41/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.3898 - val_loss: 0.9329
# Epoch 42/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.3753 - val_loss: -1.3124
# Epoch 43/150
# 4/4 [==============================] - 0s 81ms/step - loss: -1.4654 - val_loss: -0.3097
# Epoch 44/150
# 4/4 [==============================] - 0s 81ms/step - loss: -1.5028 - val_loss: -1.1688
# Epoch 45/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.4965 - val_loss: -0.9196
# Epoch 46/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.6229 - val_loss: -0.8820
# Epoch 47/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.6834 - val_loss: -0.8420
# Epoch 48/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.6467 - val_loss: -0.7547
# Epoch 49/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.6418 - val_loss: -1.0613
# Epoch 50/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.6152 - val_loss: 1.6110
# Epoch 51/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.5288 - val_loss: -1.1371
# Epoch 52/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.5768 - val_loss: -0.5776
# Epoch 53/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.6188 - val_loss: 0.1892
# Epoch 54/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.6693 - val_loss: -0.6514
# Epoch 55/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.6818 - val_loss: -0.9148
# Epoch 56/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.7433 - val_loss: -0.5788
# Epoch 57/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.7449 - val_loss: -0.0419
# Epoch 58/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.7462 - val_loss: -1.0702
# Epoch 59/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.7316 - val_loss: 0.3772
# Epoch 60/150
# 4/4 [==============================] - 0s 83ms/step - loss: -1.7867 - val_loss: -0.0865
# Epoch 61/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.7352 - val_loss: -1.2600
# Epoch 62/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.6968 - val_loss: -0.6526
# Epoch 63/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.7036 - val_loss: -0.2957
# Epoch 64/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.7363 - val_loss: -0.6171
# Epoch 65/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.8751 - val_loss: -0.8557
# Epoch 66/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.8796 - val_loss: -0.8778
# Epoch 67/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.8526 - val_loss: -1.3689
# Epoch 68/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.8125 - val_loss: 0.6184
# Epoch 69/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.8241 - val_loss: -0.8350
# Epoch 70/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.8708 - val_loss: 0.4593
# Epoch 71/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.9475 - val_loss: -0.1706
# Epoch 72/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.0101 - val_loss: -0.6243
# Epoch 73/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.9161 - val_loss: -0.8116
# Epoch 74/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.0113 - val_loss: -1.1793
# Epoch 75/150
# 4/4 [==============================] - 0s 85ms/step - loss: -2.0062 - val_loss: -1.1181
# Epoch 76/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0217 - val_loss: -0.7746
# Epoch 77/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.9884 - val_loss: -0.8223
# Epoch 78/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.8028 - val_loss: -0.1949
# Epoch 79/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.9113 - val_loss: 0.4544
# Epoch 80/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0162 - val_loss: -0.2220
# Epoch 81/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.9609 - val_loss: -1.2706
# Epoch 82/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.8338 - val_loss: 0.8108
# Epoch 83/150
# 4/4 [==============================] - 0s 82ms/step - loss: -1.7420 - val_loss: 0.0387
# Epoch 84/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.7783 - val_loss: -0.6954
# Epoch 85/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.9551 - val_loss: 0.8959
# Epoch 86/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.9891 - val_loss: -0.6981
# Epoch 87/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.9949 - val_loss: -0.8388
# Epoch 88/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.9962 - val_loss: -0.3118
# Epoch 89/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0877 - val_loss: -1.4919
# Epoch 90/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0636 - val_loss: -1.0313
# Epoch 91/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.9508 - val_loss: 0.7754
# Epoch 92/150
# 4/4 [==============================] - 0s 79ms/step - loss: -1.8984 - val_loss: -1.2449
# Epoch 93/150
# 4/4 [==============================] - 0s 81ms/step - loss: -1.9949 - val_loss: 0.6122
# Epoch 94/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.9960 - val_loss: -0.5395
# Epoch 95/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.0265 - val_loss: 0.1182
# Epoch 96/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0807 - val_loss: 0.3540
# Epoch 97/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.1654 - val_loss: -0.7690
# Epoch 98/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0993 - val_loss: -0.1705
# Epoch 99/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.1343 - val_loss: -0.3155
# Epoch 100/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1174 - val_loss: 0.0830
# Epoch 101/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.1543 - val_loss: -0.7288
# Epoch 102/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2370 - val_loss: 0.1025
# Epoch 103/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.9507 - val_loss: 0.6282
# Epoch 104/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0491 - val_loss: -1.1394
# Epoch 105/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0331 - val_loss: -0.2385
# Epoch 106/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1512 - val_loss: -1.0845
# Epoch 107/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.1440 - val_loss: -0.3673
# Epoch 108/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1369 - val_loss: -0.8748
# Epoch 109/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1587 - val_loss: -0.4189
# Epoch 110/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.1601 - val_loss: -0.6573
# Epoch 111/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.2354 - val_loss: 0.6332
# Epoch 112/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.1984 - val_loss: 0.7620
# Epoch 113/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.0430 - val_loss: -0.5106
# Epoch 114/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1257 - val_loss: -0.2215
# Epoch 115/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1911 - val_loss: 0.8432
# Epoch 116/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.1640 - val_loss: -0.5837
# Epoch 117/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2550 - val_loss: -0.3199
# Epoch 118/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.0464 - val_loss: 1.6161
# Epoch 119/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0434 - val_loss: -1.3919
# Epoch 120/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0670 - val_loss: -0.4916
# Epoch 121/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1468 - val_loss: 0.1799
# Epoch 122/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.9918 - val_loss: 2.4421
# Epoch 123/150
# 4/4 [==============================] - 0s 89ms/step - loss: -2.0135 - val_loss: 0.9920
# Epoch 124/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.0332 - val_loss: 0.8079
# Epoch 125/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.9747 - val_loss: 2.2594
# Epoch 126/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0581 - val_loss: 3.9803
# Epoch 127/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2010 - val_loss: -0.2370
# Epoch 128/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.2219 - val_loss: 1.0881
# Epoch 129/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2224 - val_loss: 0.2230
# Epoch 130/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2591 - val_loss: -0.3471
# Epoch 131/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.2635 - val_loss: -0.6994
# Epoch 132/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2380 - val_loss: -0.5008
# Epoch 133/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.2651 - val_loss: -1.1405
# Epoch 134/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2666 - val_loss: -0.6837
# Epoch 135/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2373 - val_loss: -0.0324
# Epoch 136/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2872 - val_loss: -0.3653
# Epoch 137/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2734 - val_loss: -0.7001
# Epoch 138/150
# 4/4 [==============================] - 0s 87ms/step - loss: -2.3091 - val_loss: -0.3926
# Epoch 139/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.3020 - val_loss: 0.8887
# Epoch 140/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3702 - val_loss: -0.4322
# Epoch 141/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.2116 - val_loss: -1.3509
# Epoch 142/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.2411 - val_loss: -0.4302
# Epoch 143/150
# 4/4 [==============================] - 0s 80ms/step - loss: -2.3352 - val_loss: -0.9092
# Epoch 144/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.3263 - val_loss: -0.9212
# Epoch 145/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2885 - val_loss: -0.8568
# Epoch 146/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3534 - val_loss: 0.4922
# Epoch 147/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.3397 - val_loss: -0.8558
# Epoch 148/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.3811 - val_loss: -0.8219
# Epoch 149/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.3492 - val_loss: -0.0020
# Epoch 150/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.3661 - val_loss: -0.2820
# 32/32 [==============================] - 0s 6ms/step - loss: -2.0311
# train loss: -2.031064748764038
# 100%|██████████| 30/30 [00:02<00:00, 14.26it/s]
# 100%|██████████| 30/30 [00:02<00:00, 14.80it/s]
# rmse: 0.32753286512477575
# r2: -1.2469825995219064
# For Uncertainty model, 0.7020408163265306 are in 99% confidence interval

# %%
# LSTM 모델
model3 = current.LSTM()
model3 = current.fit(model=model3, epochs = 150, batch_size = 256, show_loss = True)
LSTM_predict = current.predict_ci(model=model3, n_sample = 30, ci=2.58, show= True)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 3s 190ms/step - loss: 0.3417 - val_loss: 0.6907
# Epoch 2/150
# 4/4 [==============================] - 0s 56ms/step - loss: 0.2217 - val_loss: 0.4178
# Epoch 3/150
# 4/4 [==============================] - 0s 64ms/step - loss: 0.0990 - val_loss: 0.0888
# Epoch 4/150
# 4/4 [==============================] - 0s 71ms/step - loss: -0.0353 - val_loss: -0.2775
# Epoch 5/150
# 4/4 [==============================] - 0s 72ms/step - loss: -0.1253 - val_loss: 7.7209
# Epoch 6/150
# 4/4 [==============================] - 0s 73ms/step - loss: -0.2741 - val_loss: 14.5859
# Epoch 7/150
# 4/4 [==============================] - 0s 73ms/step - loss: -0.4834 - val_loss: 12.4979
# Epoch 8/150
# 4/4 [==============================] - 0s 75ms/step - loss: -0.7371 - val_loss: 79093.1484
# Epoch 9/150
# 4/4 [==============================] - 0s 75ms/step - loss: -0.8012 - val_loss: 132.0605
# Epoch 10/150
# 4/4 [==============================] - 0s 75ms/step - loss: -0.8285 - val_loss: 23.3192
# Epoch 11/150
# 4/4 [==============================] - 0s 74ms/step - loss: -0.9911 - val_loss: 227.4064
# Epoch 12/150
# 4/4 [==============================] - 0s 73ms/step - loss: -0.9534 - val_loss: 29.9311
# Epoch 13/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.0610 - val_loss: 33.4182
# Epoch 14/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.1316 - val_loss: 66.5158
# Epoch 15/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.1901 - val_loss: 6.7207
# Epoch 16/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.2112 - val_loss: 0.5468
# Epoch 17/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.2479 - val_loss: 3.1540
# Epoch 18/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.3457 - val_loss: 12.4681
# Epoch 19/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.2646 - val_loss: 2.0006
# Epoch 20/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.2910 - val_loss: -0.1550
# Epoch 21/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.3173 - val_loss: -0.6034
# Epoch 22/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.3800 - val_loss: 0.9113
# Epoch 23/150
# 4/4 [==============================] - 0s 80ms/step - loss: -1.4057 - val_loss: 1.4157
# Epoch 24/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.4025 - val_loss: 0.9677
# Epoch 25/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.4835 - val_loss: 2.9740e-04
# Epoch 26/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.4944 - val_loss: 1.0599
# Epoch 27/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.5679 - val_loss: -0.0310
# Epoch 28/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.6027 - val_loss: 0.5021
# Epoch 29/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.6231 - val_loss: -0.2880
# Epoch 30/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.6536 - val_loss: -0.9071
# Epoch 31/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.6799 - val_loss: -0.6897
# Epoch 32/150
# 4/4 [==============================] - 0s 77ms/step - loss: -1.7048 - val_loss: -0.7623
# Epoch 33/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.7520 - val_loss: -0.5323
# Epoch 34/150
# 4/4 [==============================] - 0s 78ms/step - loss: -1.7922 - val_loss: -0.3404
# Epoch 35/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.7849 - val_loss: -0.7512
# Epoch 36/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.8283 - val_loss: -0.5090
# Epoch 37/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.8225 - val_loss: -1.1655
# Epoch 38/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.7821 - val_loss: 0.0719
# Epoch 39/150
# 4/4 [==============================] - 0s 74ms/step - loss: -1.8422 - val_loss: -0.9721
# Epoch 40/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.8681 - val_loss: -0.8383
# Epoch 41/150
# 4/4 [==============================] - 0s 70ms/step - loss: -1.9114 - val_loss: -1.0319
# Epoch 42/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.8150 - val_loss: 0.0695
# Epoch 43/150
# 4/4 [==============================] - 0s 76ms/step - loss: -1.7715 - val_loss: -1.2349
# Epoch 44/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.8489 - val_loss: -0.7758
# Epoch 45/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.9419 - val_loss: -0.2892
# Epoch 46/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.9733 - val_loss: -0.3913
# Epoch 47/150
# 4/4 [==============================] - 0s 75ms/step - loss: -1.9860 - val_loss: -1.1156
# Epoch 48/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.9328 - val_loss: -1.2355
# Epoch 49/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.0139 - val_loss: -0.8435
# Epoch 50/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.0333 - val_loss: 0.2011
# Epoch 51/150
# 4/4 [==============================] - 0s 73ms/step - loss: -1.9813 - val_loss: -0.9964
# Epoch 52/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.0348 - val_loss: -0.8182
# Epoch 53/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.0552 - val_loss: -0.8489
# Epoch 54/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.0934 - val_loss: 0.0567
# Epoch 55/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.9597 - val_loss: 1.7933
# Epoch 56/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.0117 - val_loss: -0.9403
# Epoch 57/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.0134 - val_loss: -1.0260
# Epoch 58/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.0852 - val_loss: -0.9114
# Epoch 59/150
# 4/4 [==============================] - 0s 70ms/step - loss: -2.1147 - val_loss: -1.0293
# Epoch 60/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.0945 - val_loss: 1.1937
# Epoch 61/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.1007 - val_loss: 2.0573
# Epoch 62/150
# 4/4 [==============================] - 0s 71ms/step - loss: -2.1260 - val_loss: -0.2226
# Epoch 63/150
# 4/4 [==============================] - 0s 71ms/step - loss: -1.9680 - val_loss: -1.3129
# Epoch 64/150
# 4/4 [==============================] - 0s 72ms/step - loss: -1.9936 - val_loss: -1.1157
# Epoch 65/150
# 4/4 [==============================] - 0s 70ms/step - loss: -2.0767 - val_loss: -0.4886
# Epoch 66/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.2000 - val_loss: -0.1585
# Epoch 67/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.1098 - val_loss: -0.7944
# Epoch 68/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.1142 - val_loss: 2.3166
# Epoch 69/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.1794 - val_loss: -0.1006
# Epoch 70/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.1610 - val_loss: -1.1473
# Epoch 71/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.1090 - val_loss: 0.1813
# Epoch 72/150
# 4/4 [==============================] - 0s 81ms/step - loss: -2.1828 - val_loss: 0.3045
# Epoch 73/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.1884 - val_loss: -0.1754
# Epoch 74/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.2518 - val_loss: -0.3638
# Epoch 75/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.0806 - val_loss: -1.1539
# Epoch 76/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.1826 - val_loss: -0.1611
# Epoch 77/150
# 4/4 [==============================] - 0s 82ms/step - loss: -2.1923 - val_loss: 2.6366
# Epoch 78/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2225 - val_loss: -0.9078
# Epoch 79/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2896 - val_loss: -1.1253
# Epoch 80/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.2457 - val_loss: -1.0471
# Epoch 81/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2414 - val_loss: -0.6806
# Epoch 82/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2937 - val_loss: 0.7714
# Epoch 83/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.2559 - val_loss: -0.8875
# Epoch 84/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3088 - val_loss: -1.2684
# Epoch 85/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.3502 - val_loss: 0.0474
# Epoch 86/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.3498 - val_loss: 2.8766
# Epoch 87/150
# 4/4 [==============================] - 0s 87ms/step - loss: -2.3369 - val_loss: 0.6906
# Epoch 88/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.3279 - val_loss: -0.7162
# Epoch 89/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.3095 - val_loss: -1.4246
# Epoch 90/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.2849 - val_loss: -1.0401
# Epoch 91/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.3060 - val_loss: 1.4398
# Epoch 92/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3613 - val_loss: -0.8505
# Epoch 93/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.3181 - val_loss: -0.4863
# Epoch 94/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3471 - val_loss: -0.5949
# Epoch 95/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.2782 - val_loss: -0.4188
# Epoch 96/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3224 - val_loss: 0.1520
# Epoch 97/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.3430 - val_loss: -0.6311
# Epoch 98/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3534 - val_loss: 1.5871
# Epoch 99/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.4274 - val_loss: -0.6102
# Epoch 100/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.3202 - val_loss: 4.9142
# Epoch 101/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.3958 - val_loss: -1.2533
# Epoch 102/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.4259 - val_loss: -0.4335
# Epoch 103/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3288 - val_loss: 0.4177
# Epoch 104/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.2692 - val_loss: 0.4816
# Epoch 105/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.0879 - val_loss: -1.3418
# Epoch 106/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.2848 - val_loss: -0.2510
# Epoch 107/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2911 - val_loss: -0.8526
# Epoch 108/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.3535 - val_loss: -1.3186
# Epoch 109/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.3506 - val_loss: 0.7559
# Epoch 110/150
# 4/4 [==============================] - 0s 82ms/step - loss: -2.3390 - val_loss: 5.1286
# Epoch 111/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.3537 - val_loss: -1.1393
# Epoch 112/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.4196 - val_loss: -1.3497
# Epoch 113/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.4219 - val_loss: -0.4492
# Epoch 114/150
# 4/4 [==============================] - 0s 82ms/step - loss: -2.3817 - val_loss: -1.6688
# Epoch 115/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.3351 - val_loss: -1.4426
# Epoch 116/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.3747 - val_loss: 0.1204
# Epoch 117/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.4761 - val_loss: -0.0533
# Epoch 118/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.4617 - val_loss: -1.1635
# Epoch 119/150
# 4/4 [==============================] - 0s 82ms/step - loss: -2.3514 - val_loss: -0.4610
# Epoch 120/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.3539 - val_loss: -1.0280
# Epoch 121/150
# 4/4 [==============================] - 0s 79ms/step - loss: -2.4100 - val_loss: -1.4182
# Epoch 122/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.4652 - val_loss: 1.0363
# Epoch 123/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.4063 - val_loss: -0.6283
# Epoch 124/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.4133 - val_loss: -1.1384
# Epoch 125/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.4414 - val_loss: -0.4277
# Epoch 126/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.4652 - val_loss: -0.4874
# Epoch 127/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.4935 - val_loss: -1.3588
# Epoch 128/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.5310 - val_loss: -0.7122
# Epoch 129/150
# 4/4 [==============================] - 0s 73ms/step - loss: -2.4098 - val_loss: -1.4486
# Epoch 130/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.4777 - val_loss: -0.2084
# Epoch 131/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.5175 - val_loss: 4.2496
# Epoch 132/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.4623 - val_loss: -1.0563
# Epoch 133/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.4009 - val_loss: 0.1611
# Epoch 134/150
# 4/4 [==============================] - 0s 78ms/step - loss: -2.4086 - val_loss: -1.2795
# Epoch 135/150
# 4/4 [==============================] - 0s 85ms/step - loss: -2.4878 - val_loss: 1.1860
# Epoch 136/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.3961 - val_loss: -0.4122
# Epoch 137/150
# 4/4 [==============================] - 0s 74ms/step - loss: -2.4724 - val_loss: -0.6151
# Epoch 138/150
# 4/4 [==============================] - 0s 80ms/step - loss: -2.3983 - val_loss: -0.3538
# Epoch 139/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.4677 - val_loss: -0.2151
# Epoch 140/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.4584 - val_loss: -0.0388
# Epoch 141/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.5471 - val_loss: -1.3788
# Epoch 142/150
# 4/4 [==============================] - 0s 80ms/step - loss: -2.5670 - val_loss: -0.9512
# Epoch 143/150
# 4/4 [==============================] - 0s 72ms/step - loss: -2.4844 - val_loss: -1.5192
# Epoch 144/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.4878 - val_loss: -1.2984
# Epoch 145/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.5176 - val_loss: -1.3259
# Epoch 146/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.5264 - val_loss: -1.3775
# Epoch 147/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.2464 - val_loss: -0.9991
# Epoch 148/150
# 4/4 [==============================] - 0s 76ms/step - loss: -2.2388 - val_loss: -1.4640
# Epoch 149/150
# 4/4 [==============================] - 0s 77ms/step - loss: -2.2529 - val_loss: 1.0660
# Epoch 150/150
# 4/4 [==============================] - 0s 75ms/step - loss: -2.3883 - val_loss: -0.9266
# 32/32 [==============================] - 0s 7ms/step - loss: -2.0784
# train loss: -2.0784006118774414
# 100%|██████████| 30/30 [00:02<00:00, 10.45it/s]
# 100%|██████████| 30/30 [00:02<00:00, 12.72it/s]
# rmse: 0.2009829946147117
# r2: 0.1539255769058061
# For Uncertainty model, 1.0 are in 99% confidence interval
