# %% [markdown]
# <a href="https://colab.research.google.com/github/taeilkeemm/fordatastudy/blob/main/01_04_Kaggle_Survey_EDA(220113).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 필요한 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Kaggle Survey 데이터 불러오기

# %%
data = pd.read_csv("kaggle_survey_2020_responses.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   Time from Start to Finish (seconds)  ...                                        Q35_B_OTHER
# 0               Duration (in seconds)  ...  In the next 2 years, do you hope to become mor...
# 1                                1838  ...                                                NaN
# 2                              289287  ...                                                NaN
# 3                                 860  ...                                                NaN
# 4                                 507  ...                                                NaN
#
# [5 rows x 355 columns]

# %% [markdown]
# ### 데이터 전처리
#
# - 교육상태와 관련이 있는 column들을 고릅니다.
#
# - Data Science 실무 경력과 관련된 column들을 고릅니다.

# %%
# edu_column
# ds_column
df = data[['Q4', 'Q5', 'Q6', 'Q15', 'Q20', 'Q22']]

# %%
# null이 아닌 row만
df2 = df.dropna(axis=0)

# %%
# 결측치 제거
df2 = df2.where(pd.notnull(df2), df.mean(), axis='columns')

# %% [markdown]
# ## 교육수준과 관련된 EDA
#
# - EDA에서는 다음과 같은 항목을 살펴봅니다.
#
# > 기본적인 빈도 분석
#
# > 히스토그램
#
# > Pie chart와 같은 plotting 기법들

# %% [markdown]
# ### Q4 column
#
# **"What is the highest level of formal education that you have attained or plan to attain with the next 2 years?"**
#
# - 기본적인 matplotlib(pyplot)을 이용하여 시각화를 해봅니다.

# %%
Q4 = df2[['Q4']]
Q4
# Out:
#                                                       Q4
# 0      What is the highest level of formal education ...
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 9                                        Doctoral degree
# ...                                                  ...
# 20025                             I prefer not to answer
# 20030                                  Bachelor’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
# [10535 rows x 1 columns]

# %%
plt.figure(figsize=(16, 16))
plt.hist(Q4)
plt.title("Histogram of Q4 column")
plt.show()

# %%
plt.figure(figsize=(16, 16))
plt.pie(Q4.value_counts(),
       labels=Q4.value_counts().index,
       autopct='%d%%',
       startangle=90,
       textprops={'fontsize':12})
plt.axis('equal')
plt.title("Pie chart for Q4 column", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q4 column')

# %% [markdown]
# ### Q6 column
# **For how many years have you been writing code and/or programming?**

# %%
Q6 = df[['Q6']]
Q6
# Out:
#                                                       Q6
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
# [20037 rows x 1 columns]

# %%
plt.figure(figsize=(12, 16))
plt.hist(Q6)
plt.xticks(rotation='vertical')
plt.title("Histogram for Q6 column")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-d5b7ed3daeac> in <module>()
#       1 plt.figure(figsize=(12, 16))
# ----> 2 plt.hist(Q6)
#       3 plt.xticks(rotation='vertical')
#       4 plt.title("Histogram for Q6 column")
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6628                     # python's min/max ignore nan,
#    6629                     # np.minnan returns nan for all nan input
# -> 6630                     xmin = min(xmin, np.nanmin(xi))
#    6631                     xmax = max(xmax, np.nanmax(xi))
#    6632             # make sure we have seen at least one non-nan and finite
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     331         mask = np.all(mask, axis=axis, **kwargs)
#     332         if np.any(mask):
# --> 333             res = _copyto(res, np.nan, mask)
#     334             warnings.warn("All-NaN axis encountered", RuntimeWarning,
#     335                           stacklevel=3)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py in _copyto(a, val, mask)
#     136         np.copyto(a, val, where=mask, casting='unsafe')
#     137     else:
# --> 138         a = a.dtype.type(val)
#     139     return a
#     140
#
# AttributeError: 'float' object has no attribute 'dtype'

# %%
plt.figure(figsize=(24, 24))
plt.pie(Q6.value_counts(),
       labels=Q6.value_counts().index,
       autopct='%d%%',
       textprops={'fontsize':24})
plt.axis('equal')
plt.title("Pie chart for Q6 column", fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q6 column')

# %% [markdown]
# ### Q15 column
#
# **For how many years have you used machine learning methods?**
#
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q15 = df[['Q15']]

# %%
# countplot을 사용해봅니다

# %%
plt.figure(figsize=(8,8))
plt.pie(Q15.value_counts(),
       labels=Q15.value_counts().index,
       autopct='%d%%',
        colors=sns.color_palette('hls',len(Q15.value_counts().index)),
       textprops={'fontsize':12})
plt.axis('equal')
plt.title("Pie chart for Q15 column", fontsize=16, pad=50)
plt.show()

# %% [markdown]
# ## 직업과 관련된 EDA
#
# - EDA에서는 다음과 같은 항목을 살펴봅니다.
#
# > 기본적인 빈도 분석
#
# > 히스토그램
#
# > Pie chart와 같은 plotting 기법들

# %% [markdown]
# ### Q5 column
#
# **Select the title most similar to your current role**
#
# - 기본적인 matplotlib(pyplot)을 이용하여 시각화를 해봅니다.

# %%
Q5 = df[['Q5']]

# %%
plt.figure(figsize=(12, 12))
plt.hist(Q5)
plt.xticks(rotation='vertical')
plt.title("Histogram for Q5 column")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-0052550985af> in <module>()
#       1 plt.figure(figsize=(12, 12))
# ----> 2 plt.hist(Q5)
#       3 plt.xticks(rotation='vertical')
#       4 plt.title("Histogram for Q5 column")
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6628                     # python's min/max ignore nan,
#    6629                     # np.minnan returns nan for all nan input
# -> 6630                     xmin = min(xmin, np.nanmin(xi))
#    6631                     xmax = max(xmax, np.nanmax(xi))
#    6632             # make sure we have seen at least one non-nan and finite
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     331         mask = np.all(mask, axis=axis, **kwargs)
#     332         if np.any(mask):
# --> 333             res = _copyto(res, np.nan, mask)
#     334             warnings.warn("All-NaN axis encountered", RuntimeWarning,
#     335                           stacklevel=3)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py in _copyto(a, val, mask)
#     136         np.copyto(a, val, where=mask, casting='unsafe')
#     137     else:
# --> 138         a = a.dtype.type(val)
#     139     return a
#     140
#
# AttributeError: 'float' object has no attribute 'dtype'

# %%
plt.figure(figsize=(16, 16))
plt.pie(Q5.value_counts(),
       labels=Q5.value_counts().index,
       autopct='%d%%',
       textprops={'fontsize':24})
plt.axis('equal')
plt.title("Pie chart for Q5 column", fontsize=48, pad=50)
plt.show()

# %% [markdown]
# ### Q20 column
#
# **What is the size of the compnay where are employed?**
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q20 = df[['Q20']]

# %%
# sns.countplot을 사용해봅시다.

plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(Q20.value_counts(),
       labels=Q20.value_counts().index,
       autopct='%d%%',
        colors=sns.color_palette('hls',len(Q20.value_counts().index)),
       textprops={'fontsize':16})
plt.axis('equal')
plt.title("Pie chart for Q20 column", fontsize=32, pad=50)
plt.show()

# %% [markdown]
# ### Q22 column
#
# **Does your current employer incorporate machine learning methods into their business?**
# - seaborn을 이용해서 시각화를 해봅니다.

# %%
Q22 = df[['Q22']]

# %%
plt.figure(figsize=(12, 16))
sns.hist(Q22)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-676e5f2e4995> in <module>()
#       1 plt.figure(figsize=(12, 16))
# ----> 2 sns.hist(Q22)
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'hist'

# %%
plt.figure(figsize=(12, 12))
plt.pie(Q22.value_counts(),
       labels=Q22.value_counts().index,
       autopct='%.2f%%',
        colors=sns.color_palette('hls',len(Q22.value_counts().index)),
       textprops={'fontsize':12})
plt.axis('equal')
plt.title("Pie chart for Q22 column", fontsize=32, pad=50)
plt.show()
