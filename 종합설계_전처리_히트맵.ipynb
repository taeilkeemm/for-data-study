# %% [markdown]
# <a href="https://colab.research.google.com/github/taeilkeemm/fordatastudy/blob/main/%EC%A2%85%ED%95%A9%EC%84%A4%EA%B3%84_%EC%A0%84%EC%B2%98%EB%A6%AC_%ED%9E%88%ED%8A%B8%EB%A7%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install --upgrade pandas

# %%
df = pd.read_excel('전처리.xlsx')

# %%
df
# Out:
#      자치구     동  1인세대  2인세대  택배착지량점수(구별)    범죄발생(구별)  안심택배함수  기초생활수급자     인구  \
# 0    종로구   사직동  2356   955     1.117647  226.235294       0      590   9806
# 1    종로구   삼청동   625   252     1.117647  226.235294       0      240   2909
# 2    종로구   부암동  1689   990     1.117647  226.235294       0      489  10333
# 3    종로구   평창동  2457  1838     1.117647  226.235294       0      754  18582
# 4    종로구   무악동   703   718     1.117647  226.235294       0      334   8592
# ..   ...   ...   ...   ...          ...         ...     ...      ...    ...
# 420  강동구  암사1동  6515  3826     3.833333  223.000000       1     1476  35728
# 421  강동구  천호2동  8961  3983     3.833333  223.000000       0     1673  35251
# 422  강동구    길동  9697  4949     3.833333  223.000000       0     1572  46868
# 423  강동구   강일동  3332  3460     3.833333  223.000000       0      870  35778
# 424  강동구   상일동  3277  3816     3.833333  223.000000       0      513  33345
#
# ...

# %%
df.columns
# Out:
# Index(['자치구', '동', '1인세대', '2인세대', '택배착지량점수(구별)', '범죄발생(구별)', '안심택배함수',
#        '기초생활수급자', '인구', '면적', '인구밀도', '노령화지수', '초등학생 수(구별)', '여성인구', '장애인 수',
#        '위험경험 비율(구별)', '단독주택', '다가구주택', '아파트', '다세대주택', '우체국 수', '주차장 수',
#        '공영주차장 수', '여성 세대주 가구 수(구별)', '여성 안심 스카우트 이용실적(구별)'],
#       dtype='object')

# %%
df_numeric = df[['1인세대', '2인세대', '택배착지량점수(구별)', '범죄발생(구별)', '안심택배함수',
       '기초생활수급자', '인구', '면적', '인구밀도', '노령화지수', '초등학생 수(구별)', '여성인구', '장애인 수',
       '위험경험 비율(구별)', '단독주택', '다가구주택', '아파트', '다세대주택', '우체국 수', '주차장 수',
       '공영주차장 수', '여성 세대주 가구 수(구별)', '여성 안심 스카우트 이용실적(구별)']]

# %%
df_numeric.dtypes
# Out:
# 1인세대                     int64
# 2인세대                     int64
# 택배착지량점수(구별)            float64
# 범죄발생(구별)               float64
# 안심택배함수                   int64
# 기초생활수급자                  int64
# 인구                       int64
# 면적                     float64
# 인구밀도                     int64
# 노령화지수                  float64
# 초등학생 수(구별)             float64
# 여성인구                     int64
# 장애인 수                  float64
# 위험경험 비율(구별)            float64
# 단독주택                     int64
# 다가구주택                    int64
# 아파트                      int64
# 다세대주택                    int64
# 우체국 수                    int64
# 주차장 수                    int64
# 공영주차장 수                  int64
# 여성 세대주 가구 수(구별)        float64
# 여성 안심 스카우트 이용실적(구별)    float64
# dtype: object

# %%
df_numeric.astype('float')
# Out:
#        1인세대    2인세대  택배착지량점수(구별)    범죄발생(구별)  안심택배함수  기초생활수급자       인구    면적  \
# 0    2356.0   955.0     1.117647  226.235294     0.0    590.0   9806.0  1.23
# 1     625.0   252.0     1.117647  226.235294     0.0    240.0   2909.0  1.49
# 2    1689.0   990.0     1.117647  226.235294     0.0    489.0  10333.0  2.27
# 3    2457.0  1838.0     1.117647  226.235294     0.0    754.0  18582.0  8.87
# 4     703.0   718.0     1.117647  226.235294     0.0    334.0   8592.0  0.36
# ..      ...     ...          ...         ...     ...      ...      ...   ...
# 420  6515.0  3826.0     3.833333  223.000000     1.0   1476.0  35728.0  1.02
# 421  8961.0  3983.0     3.833333  223.000000     0.0   1673.0  35251.0  1.57
# 422  9697.0  4949.0     3.833333  223.000000     0.0   1572.0  46868.0  2.17
# 423  3332.0  3460.0     3.833333  223.000000     0.0    870.0  35778.0  2.80
# 424  3277.0  3816.0     3.833333  223.000000     0.0    513.0  33345.0  2.65
#
# ...

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(30, 30))
plt.title("Person Correlation of Features", y = 1.05, size = 15)
sns.heatmap(df_numeric.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
