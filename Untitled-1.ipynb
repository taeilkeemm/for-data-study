# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd
from tensorflow import keras
import matplotlib as mlt
import json

# %%
import PIL.Image
import tensorflow_datasets as tfds

# %%
from tensorflow.python.keras import layers
from tensorflow.python.keras.models import Sequential

# %%
from keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(rescale=1./255)

# %%
##라벨리스트
trainFileList = os.listdir('C:/Users/theil/Desktop/생활 폐기물 이미지/Training')
testFileList = os.listdir('C:/Users/theil/Desktop/생활 폐기물 이미지/Validation')

# %%
trainlabel = []
testlabel = []
for i in range(len(trainFileList)):
    trainlabel.append(trainFileList[i][5:])
for i in range(len(testFileList)):
    testlabel.append(testFileList[i][5:])

# %%
class_train_names = np.array(trainlabel)
class_test_names = np.array(testlabel)

# %%
train_generator = data_generator.flow_from_directory(
    'C:/Users/theil/Desktop/생활 폐기물 이미지/Training',
    target_size=(100, 100),
    class_mode='categorical',
    classes = list(trainFileList)
)
# Out:
# Found 556773 images belonging to 128 classes.

# %%
test_generator = data_generator.flow_from_directory(
    'C:/Users/theil/Desktop/생활 폐기물 이미지/Validation',
    target_size = (100, 100),
    class_mode='categorical',
    classes = list(testFileList)
)
# Out:
# Found 76377 images belonging to 124 classes.

# %%
for f in list_ds.take(3):
    img = image.load_img(f.numpy(), target_size=(250, 250))
    label = tf.strings.split(f, os.sep)[-2]
    print(label.numpy())
    plt.imshow(img)
    plt.show()

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(25):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.title(trainFileList[label_batch[n]==1][0].title())
        plt.axis('off')

image_batch, label_batch = next(train_generator)
show_batch(image_batch, label_batch)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39968/2403196917.py in <module>
#       8
#       9 image_batch, label_batch = next(train_generator)
# ---> 10 show_batch(image_batch, label_batch)
#
# ~\AppData\Local\Temp/ipykernel_39968/2403196917.py in show_batch(image_batch, label_batch)
#       4         ax = plt.subplot(5,5,n+1)
#       5         plt.imshow(image_batch[n])
# ----> 6         plt.title(trainFileList[label_batch[n]==1][0].title())
#       7         plt.axis('off')
#       8
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
train_generator.image_shape
# Out:
# (100, 100, 3)

# %%
from keras.layers import MaxPooling2D
from keras.layers import Conv2D
from keras.layers import Activation, Dropout, Flatten, Dense
import numpy as np
import os

# %%
num = len(trainFileList)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=X_train.shape[1:], padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 전결합층
model.add(Flatten())    # 벡터형태로 reshape
model.add(Dense(512))   # 출력
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num))
model.add(Activation('softmax'))
# 모델 구축하기
model.compile(loss='categorical_crossentropy',   # 최적화 함수 지정
    optimizer='rmsprop',
    metrics=['accuracy'])
# 모델 확인
print(model.summary())

# 학습 완료된 모델 저장
hdf5_file = "./image/7obj-model.hdf5"

# %%
#print(train_generator[0].shape)
plt.imshow(train_generator)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39968/2632716209.py in <module>
#       1 #print(train_generator[0].shape)
# ----> 2 plt.imshow(train_generator)
#       3 plt.show()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
print(y_train[0].shape)
plt.imshow(x_train[0])
plt.show()
# Out:
# (129,)

# %%
# CNN model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, losses, metrics

# %%
model = Sequential([
  x_train,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(128)
])

# %%
##이미지 아님, 은규가 준거

inputs = layers.Input(shape=(x_train.shape[1], x_train.shape[2]))

x = layers.Conv1D(filters = 256, kernel_size = 3, padding="same")(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(filters = 256, kernel_size = 3, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(filters = 256, kernel_size = 5, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.2)(x)

x = layers.Conv1D(filters = 256, kernel_size = 5, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.2)(x)

x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(129, activation=tf.nn.softmax)(x)

model = models.Model(inputs, outputs)
model.compile(optimizer=tf.optimizers.Adam(), loss =losses.SparseCategoricalCrossentropy(), metrics=[metrics.SparseCategoricalAccuracy()])

# %%
# 적용해볼 이미지 
test_image = './image/test_overturned.jpg'
# 이미지 resize
img = Image.open(test_image)
img = img.convert("RGB")
img = img.resize((64,64))
data = np.asarray(img)
X = np.array(data)
X = X.astype("float") / 256
X = X.reshape(-1, 64, 64,3)
# 예측
pred = model.predict(X)  
result = [np.argmax(value) for value in pred]   # 예측 값중 가장 높은 클래스 반환
print('New data category : ',categories[result[0]])
